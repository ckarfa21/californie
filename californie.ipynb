# %%
import pandas as pd #import de bibliotheque

# %%
cl= pd.read_csv('housing.csv')# lecture de donnees avec le code

# %%
cl.head() #afficher les premieres lignes.
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
cl['ocean_proximity'].value_counts() #afficher l'occurence des valeurs,ici elles sont au nombres de 5
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
cl.describe() #cree un code qui affiche les statistiques du jeu de donnees
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt #import de la bibliotheque pour lire le graphique

# %%
plt.figure(figsize=(20,15))
plt.hist(cl['median_house_value'],bins=50)#affiche les histogrammes des differents attributs
# Out:
# (array([   9.,   14.,   61.,  255.,  538.,  676.,  546.,  803.,  881.,
#          706.,  812.,  715.,  836.,  815.,  921.,  960.,  786.,  817.,
#          703.,  505.,  620.,  661.,  578.,  508.,  437.,  434.,  463.,
#          331.,  320.,  216.,  224.,  232.,  245.,  252.,  286.,  193.,
#          160.,  149.,  117.,  133.,  104.,   99.,   80.,   90.,  106.,
#           66.,   49.,   51.,   47., 1030.]),
#  array([ 14999.  ,  24699.04,  34399.08,  44099.12,  53799.16,  63499.2 ,
#          73199.24,  82899.28,  92599.32, 102299.36, 111999.4 , 121699.44,
#         131399.48, 141099.52, 150799.56, 160499.6 , 170199.64, 179899.68,
#         189599.72, 199299.76, 208999.8 , 218699.84, 228399.88, 238099.92,
#         247799.96, 257500.  , 267200.04, 276900.08, 286600.12, 296300.16,
#         306000.2 , 315700.24, 325400.28, 335100.32, 344800.36, 354500.4 ,
#         364200.44, 373900.48, 383600.52, 393300.56, 403000.6 , 412700.64,
# ...

# %%
plt.figure(figsize=(20,15))
plt.hist(cl['median_income'],bins=50)#affiche les histogrammes des differents attributs
# Out:
# (array([  50.,  163.,  347.,  675., 1012., 1341., 1363., 1592., 1524.,
#         1616., 1513., 1259., 1401.,  990.,  935.,  812.,  715.,  582.,
#          398.,  483.,  310.,  280.,  168.,  147.,  155.,  137.,  109.,
#           86.,   60.,   36.,   28.,   23.,   33.,   58.,   36.,   35.,
#           27.,   10.,   14.,    7.,   12.,   10.,    7.,    8.,   10.,
#            4.,    2.,    3.,    2.,   52.]),
#  array([ 0.4999  ,  0.789904,  1.079908,  1.369912,  1.659916,  1.94992 ,
#          2.239924,  2.529928,  2.819932,  3.109936,  3.39994 ,  3.689944,
#          3.979948,  4.269952,  4.559956,  4.84996 ,  5.139964,  5.429968,
#          5.719972,  6.009976,  6.29998 ,  6.589984,  6.879988,  7.169992,
#          7.459996,  7.75    ,  8.040004,  8.330008,  8.620012,  8.910016,
#          9.20002 ,  9.490024,  9.780028, 10.070032, 10.360036, 10.65004 ,
#         10.940044, 11.230048, 11.520052, 11.810056, 12.10006 , 12.390064,
# ...

# %%
plt.figure(figsize=(20,15))
plt.hist(cl['households'],bins=50)#affiche les histogrammes des differents attributs
# Out:
# (array([1.002e+03, 2.787e+03, 4.857e+03, 4.195e+03, 2.740e+03, 1.731e+03,
plt.figure(figsize=(20,15))
plt.hist(cl['total_rooms'],bins=50)#affiche les histogrammes des differents attributs
# Out:
# (array([1.489e+03, 4.665e+03, 5.653e+03, 3.672e+03, 2.046e+03, 1.115e+03,
#         5.960e+02, 4.050e+02, 2.780e+02, 1.640e+02, 1.210e+02, 8.400e+01,
#         8.500e+01, 5.300e+01, 2.900e+01, 3.100e+01, 2.300e+01, 1.600e+01,
#         1.600e+01, 1.700e+01, 1.300e+01, 1.000e+01, 1.300e+01, 8.000e+00,
#         5.000e+00, 5.000e+00, 6.000e+00, 3.000e+00, 1.000e+00, 1.000e+00,
#         3.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 0.000e+00, 3.000e+00,
#         0.000e+00, 0.000e+00, 3.000e+00, 0.000e+00, 1.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00]),
#  array([2.000000e+00, 7.883600e+02, 1.574720e+03, 2.361080e+03,
#         3.147440e+03, 3.933800e+03, 4.720160e+03, 5.506520e+03,
#         6.292880e+03, 7.079240e+03, 7.865600e+03, 8.651960e+03,
#         9.438320e+03, 1.022468e+04, 1.101104e+04, 1.179740e+04,
#         1.258376e+04, 1.337012e+04, 1.415648e+04, 1.494284e+04,
# ...

# %%
plt.figure(figsize=(20,15))
plt.hist(cl['housing_median_age'],bins=50)#affiche les histogrammes des differents attributs
# Out:
# (array([  62.,   62.,  191.,  244.,  160.,  175.,  206.,  205.,  264.,
#          254.,  238.,  302.,  412.,  512.,  771.,  698.,  570.,  502.,
#          465.,  446.,  399.,  448.,  478.,  566.,  619.,  488.,  471.,
#          461.,  476.,  458.,  565.,  615.,  689.,  824.,  862.,  537.,
#          394.,  369.,  304.,  296.,  368.,  353.,  356.,  294.,  245.,
#          198.,  177.,  134.,  136., 1321.]),
#  array([ 1.  ,  2.02,  3.04,  4.06,  5.08,  6.1 ,  7.12,  8.14,  9.16,
#         10.18, 11.2 , 12.22, 13.24, 14.26, 15.28, 16.3 , 17.32, 18.34,
#         19.36, 20.38, 21.4 , 22.42, 23.44, 24.46, 25.48, 26.5 , 27.52,
#         28.54, 29.56, 30.58, 31.6 , 32.62, 33.64, 34.66, 35.68, 36.7 ,
#         37.72, 38.74, 39.76, 40.78, 41.8 , 42.82, 43.84, 44.86, 45.88,
#         46.9 , 47.92, 48.94, 49.96, 50.98, 52.  ]),
#  <BarContainer object of 50 artists>)

# %%
plt.figure(figsize=(20,15))
plt.hist(cl['latitude'],bins=50)#affiche les histogrammes des differents attributs
# Out:
# (array([ 396.,  817.,  225.,  250.,  108.,  436., 1773., 3083., 3086.,
#          609.,  250.,  131.,  126.,   74.,  166.,  178.,   62.,   33.,
#           76.,  125.,  162.,  247.,  457.,  250.,  176.,  999.,  632.,
#         1571., 1055.,  455.,  336.,  500.,  585.,  145.,  174.,  192.,
#          102.,   53.,  111.,   32.,   43.,   41.,  115.,   79.,   46.,
#           14.,   15.,   12.,   18.,   19.]),
#  array([32.54  , 32.7282, 32.9164, 33.1046, 33.2928, 33.481 , 33.6692,
#         33.8574, 34.0456, 34.2338, 34.422 , 34.6102, 34.7984, 34.9866,
#         35.1748, 35.363 , 35.5512, 35.7394, 35.9276, 36.1158, 36.304 ,
#         36.4922, 36.6804, 36.8686, 37.0568, 37.245 , 37.4332, 37.6214,
#         37.8096, 37.9978, 38.186 , 38.3742, 38.5624, 38.7506, 38.9388,
#         39.127 , 39.3152, 39.5034, 39.6916, 39.8798, 40.068 , 40.2562,
#         40.4444, 40.6326, 40.8208, 41.009 , 41.1972, 41.3854, 41.5736,
#         41.7618, 41.95  ]),
#  <BarContainer object of 50 artists>)

# %%
plt.figure(figsize=(20,15))
plt.hist(cl['longitude'],bins=50)#affiche les histogrammes des differents attributs
# Out:
# (array([5.900e+01, 6.600e+01, 2.600e+01, 1.400e+01, 2.500e+01, 4.800e+01,
#         3.700e+01, 1.310e+02, 3.120e+02, 1.025e+03, 1.295e+03, 1.312e+03,
#         9.760e+02, 3.380e+02, 6.430e+02, 6.330e+02, 3.600e+02, 2.200e+02,
#         2.110e+02, 2.490e+02, 1.110e+02, 1.550e+02, 3.790e+02, 3.180e+02,
#         1.350e+02, 3.330e+02, 3.690e+02, 1.560e+02, 2.760e+02, 1.753e+03,
#         2.507e+03, 1.718e+03, 1.035e+03, 5.490e+02, 3.990e+02, 1.090e+03,
#         9.200e+02, 1.240e+02, 4.400e+01, 7.400e+01, 5.500e+01, 1.900e+01,
#         1.300e+01, 7.000e+01, 2.600e+01, 1.000e+00, 3.000e+00, 1.000e+00,
#         2.400e+01, 3.000e+00]),
#  array([-124.35  , -124.1492, -123.9484, -123.7476, -123.5468, -123.346 ,
#         -123.1452, -122.9444, -122.7436, -122.5428, -122.342 , -122.1412,
#         -121.9404, -121.7396, -121.5388, -121.338 , -121.1372, -120.9364,
#         -120.7356, -120.5348, -120.334 , -120.1332, -119.9324, -119.7316,
# ...

# %%
#Créez un code qui partitionne les données en base d’apprentissage et base de test.
#Optezpour 80% pour l’apprentissage et 20% pour le test.
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X = cl.iloc[:, [0,1,2, 3,4]].values
y = cl.iloc[:, 4].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from matplotlib import pyplot as plt
cl.plot.scatter("longitude", "latitude",alpha=0.2)
plt.show()

# %%
cl.plot.scatter("longitude", "latitude",alpha=0.2,c="median_house_value",sharex="false",colormap='coolwarm')
plt.show()
#Créez un code qui permet d’avoir une idée sur le lien entre la position géographique et leprix des maisons (target).
#Optez pour une valeur égale à False de "sharex"

# %%
#Modifiez le graphe de la question précédente pour savoir la raison du prix élevé de quelques maisons.
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
img = mpimg.imread('california.png')
cl.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1,
label="population", c="median_house_value", colormap='gist_rainbow', colorbar=True, sharex=False, 
figsize=(10,7))
plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5,
           cmap=plt.get_cmap("jet"))
plt.legend()

# %%
cl.corr().loc[["median_house_value"]
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# median_house_value  -0.045967  -0.14416            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# median_house_value        0.049686    -0.02465    0.065843       0.688075
#
#                     median_house_value
# median_house_value                 1.0

# %% [markdown]
# la valeur moyenne d'une maison augmente suivant la moyenne du salaire.

# %% [markdown]
# Nettoyage des données

# %%
#Créez un code permettant de créer deux variables :
#Une première contenant que les input. Utilisez la fonction drop du module panda
a=("latitude")
d=X,Y
d=d.dropna()
d

# %%
#Dans la question 8, vous avez dû remarquer que l’attribut"total_bedrooms"a des valeursmanquantes (NaN).
#Pour remédier à ceci, il existes trois options ,Remplacer les valeurs manquantes par une autre valeur (0)
# Remplacer en utilisant la médiane
median = cl['total_bedrooms'].median()
cl['total_bedrooms'].fillna(median, inplace=True)
cl.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#Les algorithmes d’apprentissage profond préfère de travailler avec les données numériques.
#Ceci est valable pour tous les attributs sauf"ocean_proximity".
#Vérifiez ceci en affichant 10de ces valeurs. Transformer les valeurs qualitatives en des valeurs numériques
# Remplacement basée sur une position
import numpy as np
nan_replaced = cl.replace(np.nan,125)
cl.loc['ocean_proximity '] = 125
print(nan_replaced)
# Out:
#                   longitude  latitude  housing_median_age  total_rooms  \
# 0                   -122.23     37.88                41.0        880.0
# 1                   -122.22     37.86                21.0       7099.0
# 2                   -122.24     37.85                52.0       1467.0
# 3                   -122.25     37.85                52.0       1274.0
# 4                   -122.25     37.85                52.0       1627.0
# ...                     ...       ...                 ...          ...
# 20638               -121.32     39.43                18.0       1860.0
# 20639               -121.24     39.37                16.0       2785.0
#                      125.00    125.00               125.0        125.0
# 20641                125.00    125.00               125.0        125.0
# ocean_proximity      125.00    125.00               125.0        125.0
#
#                   total_bedrooms  population  households  median_income  \
# ...

# %%
# des valeurs manquantes?
print(cl.isnull().values.any())
# Out:
# True

# %%
# Nombre total de valeurs manquantes
print(cl.isnull().sum().sum())
# Out:
# 20659

# %%
# Remplacer les valeurs manquantes par un nombre
cl.fillna(125, inplace=True)
cl.info
# Out:
# <bound method DataFrame.info of                   longitude  latitude  housing_median_age  total_rooms  \
# 0                   -122.23     37.88                41.0        880.0
# 1                   -122.22     37.86                21.0       7099.0
# 2                   -122.24     37.85                52.0       1467.0
# 3                   -122.25     37.85                52.0       1274.0
# 4                   -122.25     37.85                52.0       1627.0
# ...                     ...       ...                 ...          ...
# 20638               -121.32     39.43                18.0       1860.0
# 20639               -121.24     39.37                16.0       2785.0
#                      125.00    125.00               125.0        125.0
# 20641                125.00    125.00               125.0        125.0
# ocean_proximity      125.00    125.00               125.0        125.0
#
#                   total_bedrooms  population  households  median_income  \
# ...

# %%
# Nombre total de valeurs manquantes
print(cl.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# Sélection, apprentissage et évaluation du modèle

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting Logistic Regression to the Training set
#cla= LogisticRegression(random_state = 0, solver='lbfgs', multi_class='auto')
#cla.fit(X_train, y_train)

# Predicting the Test set results
#y_pred = classifier.predict(X_test)
# Predict probabilities
#probs_y=classifier.predict_proba(X_test)
